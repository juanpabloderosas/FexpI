# %%
# Borra consola, variables y funciones definidas en el entorno Global
rm(list = setdiff(ls(), lsf.str()));
rm(list=lsf.str());
cat("\014") #borra consola

# %%
#librerías (si R no tiene instaladas, las instala con "install.packages(libreria)")
if(suppressWarnings(library("jpeg", logical.return = T ) == FALSE)) +
{install.packages("jpeg")} 

if(suppressWarnings(library("crayon", logical.return = T ) == FALSE)) +
{install.packages("crayon")} 
library("jpeg");library("ggplot2");library("crayon");
fig <- function(width, heigth){
 options(repr.plot.width = width, repr.plot.height = heigth)
 }
# Out:
# Attaching package: ‘ggplot2’
#
#
# The following object is masked from ‘package:crayon’:
#
#     %+%

# %% [markdown]
# # F Exp I - Clase 1 - Software

# %% [markdown]
# # Holas digitales
#
# Yo: Juan Pablo de Rosas (un servidor)

# %% [markdown]
# ## Horarios:
#
# ### Estas clases:
# Lunes 9:30 hs
# ### Consultas/Entregas:
# Viernes 9:30 hs. Entrega *durante* el viernes.
#
# ### Vías de comunicación:
#
# + Mi mail: juanpabloderosas@gmail.com
#
# + Google Classroom
#
# + Estas videoconferencias, con estos archivos de extensión rara, *.ipynb ó *.html. (Los voy a ir dejando en Drive o el Classroom, para que copipasteen código)

# %% [markdown]
# ## La Pandemia
#
# + Es una ***mala suerte*** que estudiantes de primer año tengan que afrontar esta situación (lo lamentamos mucho).
#
# + Es peor suerte la que corren les médiques, les ancianes, les enfermes (intentemos no quejarnos por nada mientras estemos sanes)

# %% [markdown]
# + La pandemia no sale de la nada: hay pandemia por:
#
#    + Hiperconectividad global: barcos, aviones, comercio desmedido: si el virus hubiera salido en Wuhan, China, hace 50 años, se hubiera quedado ahí probablemente.
#    + Zoonosis: China crece económicamente a ***tasas chinas***, lo que expande mucho el contacto entre las ciudades y los ecosistemas: alta probabilidad de intercambiar patógenos: en los últimos 15 años cuento tres virus en mi cabeza Sars-Cov 1 y 2 (es una muy mala peli en dos partes) y H1N1.

# %% [markdown]
# # ¿Qué hace un estudiante de física en cuanto a la pandemia?
#
# + Se queda en casa y les cree a los infectólogos (no hace discusiones ***nonsense*** intentando discutirle a médicos, infectólogos, virólogos, matemáticos o físicos que estudian el tema).
#
#
# + Puede hacer modelos de propagación y análisis de datos de la pandemia (tal vez hagamos un par). Ver: __[Yaneer Ban-Yam](https://en.wikipedia.org/wiki/Yaneer_Bar-Yam)__; ejemplos locales: __[Ezequiel Álvarez, un conocido de esta Alta Casa de Estudios](https://www.lanacion.com.ar/tecnologia/las-nuevas-tecnologias-salen-dar-batalla-pandemia-nid2355253)__ . También, si no les gusta la Nazión, __[Ezequiel Álvarez ](https://www.pagina12.com.ar/256315-inteligencia-artificial-contra-el-coronavirus-la-apuesta-de-)__.
#
#
# + Puede hacer la limpieza (cocinar, hacer las compras, ayudar en general) en la casa, porque todes deben estar hastiades.

# %% [markdown]
# ## ¿Para qué sirven estas clases?

# %% [markdown]
# ### En física Experimental:
# 1. Aprendemos un poco a hacer experimentos.
#
# 1. Aprendemos a analizar incertezas en las medidas
#
# 1. Aprendemos a interpretar datos y modelos.
#
# 1. Aprendemos a concluír un trabajo de investigación nivel semidios..

# %% [markdown]
# ### En estas clases vamos a aprender a ***hacer código en R*** para:
#
# 1. Analizar los resultados de nuestros experimentos.
#
# 1. Sacar cuentas complicadas que no se pueden hacer a mano (poco).
#
# 1. Hacer gráficos.
#
# 1. Analizar datos
#     1. Gráficamente.
#     1. Con estimadores estadísticos
#
# 1. Comparar resultados.

# %% [markdown]
# # 10. ¿Por qué estudian física?

# %% [markdown]
# <img src="https://media1.tenor.com/images/3d06d6ac5a22d245bce66d453f2fad7c/tenor.gif?itemid=4810969" width="1000"/>

# %% [markdown]
# # CONSEJOS PARA HACER EMPANADAS
#
# #### Le robé a Alberto Rojo algunos consejos, otros los descarté y agregué cosas propias.
#
# + Alberto Rojo es un físico argentino, muy capo, que hace mucha divulgación, es músico y pintor, aparte de físico. Vive en los Estados Unidos de América (yankeelandia). Trabaja en superconductividad (como nuestra jefa de cátedra).

# %% [markdown]
# ### 9. Trabajar, terminar, publicar (escribir...)
# + Cuando hagan un laburo de esta materia, intenten concentrarse en el **fin** de lo que quieren hacer.
#
# + Si tienen que entregar un trabajo sepan que:
#
#     + Interpretar y calcular demora.
#     + Hacer los grafiquitos bonitos (entendibles) demora tb.
#     + Escribir demora más. Y peor: ahí aparecen las dudas y las reinterpretaciones. No demoren hasta el último día para escribir, porque va a salir mal.

# %% [markdown]
# ## 9.a. Practiquen sus capacidades de escritura.
#
# + Aunque estemos en un ámbito técnico:
#
#     + Escribir aclara la mente.
#     + Es lindo leer textos bien pensados.
#     + Ojo con pensar que leer es aburrido y la física, el código, tutti se va a aprender por "ósmosis".

# %% [markdown]
# ## 8. Hagan (todos) los ejercicios de la tarea (y si quieren otro consejo: de todas las materias que estén cursando).
#
# + Los ejercicios están pensados para (a) entrenar, (b) discutir, (c) divertirse...
#
# + Discutiendo con nos o entre ustedes es como más van a a aprender (dado que hayan leído lo suficiente). Expresar ideas aclara los conceptos.

# %% [markdown]
# ## 7. Intentar comprender lo que no parece comprensible.
#
# No es sólo para programar, sino para cualquier actividad....
#
# + Imposible es aprender sin dificultad. En física existe una tendencia (tonta) a pensar que si ***estás destinade*** a ser quien revolucione la física del S XXI entonces aprendés sin dificultad. Y si no aprendés sin dificultad entonces no servís para la física: ***FALACIA NIVEL DIOS***
#
#
# + Falacia de cómo se hace física: la física se hace de muchas formas, pero una particularmente popular (y la que generalmente tienen en la cabeza) es la de **un hombre** con un papelito, pensando. La realidad: mucho código y mucho labo, pocos con papelito (aunque los hay...). Con respecto a los labos: hacer experimentitos, con ganas, incrementa mucho el conocimiento que se tiene en física: Einstein tenía un laboratorio en la casa desde los 12 años...

# %% [markdown]
# ## 7.a. Toleren un ***entendimiento parcial***.
#
#
#  + Creer que ***deben*** entender todo rápido sólo conduce a la ***frustración***: es ***paralizante***.
#
#
#  + No todo se entiende ***de una***. Ciertos temas suenan a chino al comienzo, pero se puede comprender un solo concepto y luego ***ir conectando puntos*** hasta tener una imagen más completa.
#
#
#  + Si persisten, entonces van a lograr que sus puntitos sean algo menos pixelados, hasta poder ver una imágen.
#
#  <img src="https://media1.tenor.com/images/3a40a6675a171c540f1ed48968b4457f/tenor.gif?itemid=17126018" width="500"/>

# %% [markdown]
# ## 6.  __[Séneca](https://es.wikipedia.org/wiki/S%C3%A9neca)__ decía: "El hombre, enseñando, aprende"
#
#
# + Explicarle cosas a quien quiera escuchar...no tanto porque vayan a iluminar a alguien, sino porque al ***verbalizar*** se incorporan y asimilan los conceptos. Ojo que explicarle a quien ya sabe es una trampa: hay que explicarle al kioskere, a les abueles, a le hermanite (el inclusivo no me sale natural, pero es una manera de plantar posición, *ergo*, lo intento).
#
#
#
# + Escribir aclara más...y lo van a hacer durante el curso, pero es recomendable que lo hagan con todo lo que se les ocurra. El texto es la piedra de la que el pensamiento está hecho.

# %% [markdown]
# ## 5.  No tengan miedo de hacer preguntas que ***ustedes*** consideran triviales...
#
# + En clase, entre ustedes, etc.
#
#
# + Hay ciertos procesos mentales que pasan si quieren formular la pregunta: muchas veces, al estar dos días pensando cómo resolver un problema, al intentar formular la pregunta para alguien...aparece la respuesta...y nuevas preguntas.

# %% [markdown]
# ## 4. No se comparen con ***otres***
#
# + Entender no es exclusivo de ***genie***: depende de la familiaridad con un lenguaje (mientras más se sabe, más fácil es entender cosas nuevas)
#
#
# + Los ritmos pueden ser muy distintos entre diferentes personas, y no por eso ***une es peor que otre***. Algunes van más rápido, otres más lento. No es una carrera de 100 m con obstáculos, y la rapidez no es sinónimo de virtud (raro hablar de esto en un mundo tan productivista).
#
#
# + Lo más importante para adquirir es la ***profundidad***, que es el extremo donde aparecen ***nuevas*** preguntas. Esto puede demorar años, por ahora a aprender como se pueda (tampoco somos hippies y que *la vida les enseñará*)

# %% [markdown]
# ## 3. Aprendan lo que necesitan.
#
# Una vez planteado un objetivo (hacer un gráfico, escribir un trabajo de labo, interpretar resultados, hacer código):
#
# #### Busquen lo que se necesita para llegar a ese objetivo. Hay:
#
# + Brolis.
#
# + Internet.
#
# + Consultas (ojo que si piden repetidamente que solucionemos la tarea, entonces no van a aprender nada)

# %% [markdown]
# ## 2. Llévense bien entre ustedes y con nosotres.
#
# + No hagan disputas sonzas entre ustedes.
#
#
# + No se maltraten al dope.
#
#
# + Charlando entre ustedes es como más van a aprender.
#
#
# + Intercambien código libremente, pero sólo luego de intentar hacerlo repetidas veces y que no salga.
#
#
# + Disfruten en grupo. Trabajen en grupo. No se  corten sol***e***s (una coma nos agregaría risa, como pasó con Sarmiento).

# %% [markdown]
# ## 4. No elucubren un mundo paralelo
#
#
# Seguro que tienen un montón de ideas sobre lo que es hacer física. Entre otras cosas, hacer física podría ser mirar la misma realidad de todos los días, con ciertos anteojos.
#
# ***"Hay otro mundo, y está dentro de éste." Paul Eluard.***
#
#
# Ejercitar una ciencia es calzarse unos anteojos. En este curso:
#
# + No vamos a apretar botones para medir y comparar un modelo de física de partículas.
#
# + No vamos a ver fenómenos ***raros*** (en realidad, que ustedes consideren raros): vamos a ver fenómenos de física 1: piedritas, medidas de longitud...boludeces que sólo interesan si les dedicamos el tiempo y las ganas.
#
# + No vamos a complicar los modelos físicos, pero un poquito los de datos.
